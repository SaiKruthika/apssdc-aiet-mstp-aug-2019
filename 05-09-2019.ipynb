# %% [markdown]
# # markdown introduction

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*

# %% [markdown]
# <strike>striked text</strike>

# %% [markdown]
# <strike>striked text</strike><br/>
# 'highlighted text'

# %% [markdown]
# *italic*
# hi<br/>'highlighted text'

# %% [markdown]
# <img src="https://mpng.pngfly.com/20181115/ttc/kisspng-programming-python-logo-programming-language-compu-data-analysis-course-st-hua-private-school-5bedd96a011543.8733544715423143460044.jpg">

# %% [markdown]
# # heading

# %% [markdown]
# ## heading

# %% [markdown]
# ### heading

# %% [markdown]
# #### heading

# %% [markdown]
# ##### heading

# %% [markdown]
# ###### heading

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%html
# <iframe width="697" height="392" src="https://www.youtube.com/embed/QXeEoD0pB3E?list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="697" height="392" src="https://www.youtube.com/embed/QXeEoD0pB3E?list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * R programming
# * scripting languages
#  - html
#  - css
#  - xml

# %%
print("hello world")
print("apssdc")
# Out:
# hello world
# apssdc

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # operators

# %% [markdown]
# * Arithematic operators
# * Logical operatos
# * Relational operators

# %% [markdown]
# # Arithematic operators

# %%
print(10)
# Out:
# 10

# %%
print(2+3)
# Out:
# 5

# %%
print(3*6)
# Out:
# 18

# %%
print(9-6)
# Out:
# 3

# %%
type(1)
# Out:
# int

# %%
type(10/3)
# Out:
# float

# %%
type(10//3)
# Out:
# int

# %%
10//3
# Out:
# 3

# %%
10/5
# Out:
# 2.0

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
10%3
# Out:
# 1

# %% [markdown]
# # Logical operators

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # Relational operators

# %%
2<3
# Out:
# True

# %%
2>3
# Out:
# False

# %%
2==4
# Out:
# False

# %%
2!=6
# Out:
# True

# %%
2<=3
# Out:
# True

# %%
2>=3
# Out:
# False

# %% [markdown]
# # Assignment operators

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
a="kruthi"

# %%
type(a)
# Out:
# str

# %%
print(a)
# Out:
# kruthi

# %%
b="kruthi"

# %%
a==b
# Out:
# True

# %%
b="kruthika"

# %%
a==b
# Out:
# False

# %%
print(a,b)
# Out:
# kruthi kruthika

# %%
a=5.90

# %%
type(a)
# Out:
# float

# %%
a=b=c=10

# %%
print(a,b,c)
# Out:
# 10 10 10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
a="kruthi"

# %%
a
# Out:
# 'kruthi'

# %%
a=0,b=9,c=8
# Out:
#   File "<ipython-input-57-9beabfc5c87b>", line 1
#     a=0,b=9,c=8
#      ^
# SyntaxError: can't assign to literal

# %%
a=0

# %%
a,b,c=1,2,3

# %%
a,b,c
# Out:
# (1, 2, 3)

# %%
a
b
c
# Out:
# 3

# %%
a
b
# Out:
# 2

# %%
a
# Out:
# 1

# %%
a=9

# %%
a
b
c
# Out:
# 3

# %%
c=6

# %%
a
b
c
# Out:
# 6

# %%
print(a)
print(b)
c
# Out:
# 2
# 9
# 6

# %%
a,b
# Out:
# (2, 9)

# %%
a,b=b,a

# %%
a,b
# Out:
# (9, 2)

# %%
a++ #it is not supported
# Out:
#   File "<ipython-input-76-ae790910f863>", line 1
#     a++ #it is not supported
#                             ^
# SyntaxError: invalid syntax

# %%
a++ #it is not supported
# Out:
#   File "<ipython-input-77-ae790910f863>", line 1
#     a++ #it is not supported
#                             ^
# SyntaxError: invalid syntax

# %%
a=a+1
a
# Out:
# 10

# %%
a+=1
a
# Out:
# 11

# %%
a-=1
a
# Out:
# 10

# %%
a/=2
a
# Out:
# 5.0

# %%
a%=2
a
# Out:
# 1.0

# %%
a//=2
a
# Out:
# 0.0

# %%
a//=3

# %%
a
# Out:
# 0.0

# %%
a=10
a//=3
a
# Out:
# 3

# %%
a=10

# %%
a//=3
a
# Out:
# 3

# %%
a/=5

# %%
a
# Out:
# 0.6

# %% [markdown]
# # Bitwise operators

# %%
4&7
# Out:
# 4

# %%
4&4
# Out:
# 4

# %%
4|7
# Out:
# 7

# %%
4&7&8&6&0
# Out:
# 0

# %%
7|5|4|8|0
# Out:
# 15

# %%
7|5|9
# Out:
# 15

# %%
4&6&5&8&9
# Out:
# 0

# %%
8<<6
# Out:
# 512

# %%
8<<2
# Out:
# 32

# %%
8>>2
# Out:
# 2

# %%
4<<2
# Out:
# 16

# %% [markdown]
# # Identity operators
# * is
# * is not

# %%
2==3
# Out:
# False

# %%
2==2
# Out:
# True

# %%
2 is 3
# Out:
# False

# %%
2 is 2
# Out:
# True

# %%
2!=3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# # Membership operators
# * in
# * not in

# %%
"ap" in "pappu"
# Out:
# True

# %%
"Ap" in "pappu"
# Out:
# False

# %%
"a" in "susmi"
# Out:
# False

# %%
'a' in 'kruthika'
# Out:
# True

# %%
't' not in 'yami'
# Out:
# True
